# %% [markdown]
# # Data Commons - Cloud Run Deployment
#
# **Interactive deployment** - Run each cell with Shift+Enter
#
# ---
#
# ## Step 1: Run Automated Deployment
#
# The tool will ask you 4 questions:
# 1. **Which project?** Type to filter, arrow to select
# 2. **Service name?** Default: datacommons-service
# 3. **Which region?** Pick closest to your users
# 4. **Public access?** Yes = anyone can access
#
# Click the cell below and press **Shift+Enter** or click play button:

# %%
# !/usr/bin/python setup.py

# %% [markdown]
# ---
#
# ## Step 2: Cleanup
#
# **Warning:** This will delete your deployed resources
#
# Click the cell below and press **Shift+Enter** or click play button:

# %%
# !./cleanup.sh
