# %% [markdown]
# # Data Commons - Cloud Run Deployment
#
# **Interactive deployment notebook** - Run each cell to deploy your service.
#
# ---

# %% [markdown]
# ## Step 1: Run Automated Deployment
#
# This launches the interactive deployment tool.
#
# **You'll answer 4 questions:**
# 1. Which GCP project? (type to filter)
# 2. Service name? (default: datacommons-service)
# 3. Deployment region? (pick closest to users)
# 4. Public access? (yes/no)
#
# **Click below and press Shift+Enter:**

# %%
# Click play button to run interactive deployment
# !python3 setup.py

# %% [markdown]
# ## Step 2: Cleanup
#
#  **Warning:** This deletes your deployed resources

# %%
# Click play button to run cleanup
# !./cleanup.sh
